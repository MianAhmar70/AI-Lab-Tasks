# %%
from datetime import datetime
class task:
    def __init__(self,task_name,task_desciption,date):
        self.task_name=task_name
        self.task_desciption=task_desciption
        self.date=date
        self.Copmpleted=False
    def __str__(self) :
        action="completed" if self.Copmpleted else "Not completed"
        return f"task_name is:{self.task_name},task description is:{self.task_desciption},task date is:{self.date},action is:{action}"
class To_Do_List():
    def __init__(self):
        self.tasks=[]
        
    def add_task(self,task_name,task_desciption,date):
        Task=task(task_name,task_desciption,date)
        self.tasks.append(Task)
        
    def del_task(self,task_name):
        for task in self.tasks:
            if task_name in self.tasks:
                self.tasks.remove(task)
                print("task is deleted")
                break
            else:
                print("task name is not found")
                
    def completed_task(self,task_name):
        for task in self.tasks:
            if task_name in self.tasks:
                task.completed=True
                print("task is completed")
                break
            else:
                print("task name is not found")
                
    def sort(self):
        self.tasks.sort(key=lambda x: (x.completed, x.date))
        
    def display_tasks(self):
        if not  self.tasks:
            print("no task found")
        else:
            for Task in self.tasks:
                print(Task)
                
ToDo_list=To_Do_List()
while True:
    print("To_D0_List ")
    print("1.Add task")
    print("2.Delete Task")
    print("3.Completed task")
    print("4.Sort tasks")
    print("5.Display tasks")
    print("6.Exit")
    choice=int(input("Enter your choice:"))
    if choice==1:
        task_name=input("Enter task name:")
        task_description=input("Enter task description:")
        priority=int(input("Enter task priority:"))
        date=input("Enter task date:")
        ToDo_list.add_task(task_name,task_description,date)
        print("task addeed successfully")
    elif choice==2:
        task_name=input("Enter task name:")
        ToDo_list.del_task(task_name)
    elif choice==3:
        task_name=input("Enter task name:")
        ToDo_list.completed_task(task_name)
    elif choice==4:
        ToDo_list.sort()
    elif choice==5:
        print("Your tasks:")
        ToDo_list.display_tasks()
    elif choice==6:
        print("Thanks for using a To Do List")
        break
    else:
         print("Your chice is not existing in the menue")
# Out:
# To_D0_List
# 1.Add task
# 2.Delete Task
# 3.Completed task
# 4.Sort tasks
# 5.Display tasks
# 6.Exit
# task addeed successfully
# To_D0_List
# 1.Add task
# 2.Delete Task
# 3.Completed task
# 4.Sort tasks
# 5.Display tasks
# 6.Exit
# Your tasks:
# task_name is:assignment,task description is:ai lab,task date is:21-08-2024,action is:Not completed
# To_D0_List
# 1.Add task
# 2.Delete Task
# 3.Completed task
# 4.Sort tasks
# 5.Display tasks
# 6.Exit
# Thanks for using a To Do List
